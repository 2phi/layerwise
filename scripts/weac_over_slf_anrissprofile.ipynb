# %%
# Auto reload modules
# %load_ext autoreload
# %autoreload all

# %%
import numpy as np
import pandas as pd
import os
from tqdm.notebook import tqdm

from weac.components import Segment, ScenarioConfig, WeakLayer, CriteriaConfig, WEAK_LAYER
from weac.analysis import CriteriaEvaluator
from weac.utils.snowpilot_parser import convert_to_mm, convert_to_deg

from layerwise.analysis.profile_utils import load_snowpilot_parsers, eval_avalanche_pit

# %%
## Settings
run_weac = True
dev = False
discard_pits_with_wl_above = 50 # mm

## Setup standard values

raw_data_dir = "../data/raw/slf-anrissprofile"
csv_file = "../data/misc/weac_over_slf_anrissprofile.csv"


phi = 35.0
scenario_config = ScenarioConfig(system_type="skier", phi=phi)
weak_layer = WEAK_LAYER
segments = [
    Segment(length=10000, has_foundation=True, m=0.0),
    Segment(
        length=10000,
        has_foundation=True,
        m=0.0,
    ),
]
criteria_config = CriteriaConfig()
criteria_evaluator = CriteriaEvaluator(criteria_config)

# %%
def extract_avalanche_fracture_depth(p):
    """
    Extract the depth of the avalanche fracture from the snowpit.
    """
    return p.snowpit.snow_profile.layer_of_concern.depth_top[0] * convert_to_mm[p.snowpit.snow_profile.layer_of_concern.depth_top[1]]

# %%
## Parse all snowpilot files near an avalanche and a layer of concern

paths, parsers = load_snowpilot_parsers(raw_data_dir)

print("Overall number of files:", len(paths))

paths_and_parsers = [
    (fp, pars)
    for fp, pars in zip(paths, parsers)
]

paths_and_parsers_near_avalanche = [
    (fp, p)
    for fp, p in paths_and_parsers
    if bool(p.snowpit.core_info.location.pit_near_avalanche)
]

# print the ones that are not near avalanche
for fp, p in paths_and_parsers:
    if not bool(p.snowpit.core_info.location.pit_near_avalanche):
        print(fp)

print("Number of files near avalanche:", len(paths_and_parsers_near_avalanche))

avalanche_pits_with_layer_of_concern = [
    (fp, p)
    for fp, p in paths_and_parsers_near_avalanche
    if bool(p.snowpit.core_info.location.avalanche_initiation_height)
]

print("Number of files with layer of concern:", len(avalanche_pits_with_layer_of_concern))

if dev:
    avalanche_pits_with_layer_of_concern = avalanche_pits_with_layer_of_concern[:5]
# Out:
# Overall number of files: 292
# Number of files near avalanche: 292
# Number of files with layer of concern: 292

# %%
# Extract additional pit information

pit_info_list = []
for _, pit in avalanche_pits_with_layer_of_concern:
    hs = pit.snowpit.snow_profile.hs
    if hs:
        hs_mm = hs[0] * convert_to_mm[hs[1]]
    else:
        hs_mm = None
    profile_depth = pit.snowpit.snow_profile.profile_depth
    if profile_depth:
        profile_depth_mm = profile_depth[0] * convert_to_mm[profile_depth[1]]
    else:
        profile_depth_mm = None
    height_bottom = pit.snowpit.core_info.location.avalanche_initiation_height
    if height_bottom:
        height_bottom_mm = height_bottom[0] * convert_to_mm[height_bottom[1]]
        depth_top_mm = hs_mm - height_bottom_mm
        print(f"hs_mm: {hs_mm}, height_bottom_mm: {height_bottom_mm}, depth_top_mm: {depth_top_mm}")
    else:
        height_bottom_mm = None
        depth_top_mm = None
    slope_angle = pit.snowpit.core_info.location.slope_angle
    if slope_angle:
        slope_angle_deg = slope_angle[0] * convert_to_deg[slope_angle[1]]
    else:
        slope_angle_deg = 0.0
    pit_near_avalanche_location = pit.snowpit.core_info.location.pit_near_avalanche_location
    pit_info_dict = {
        "Slope Angle": slope_angle_deg,
        "HS": hs_mm,
        "Profile Depth": profile_depth_mm,
        "WL_Depth": depth_top_mm,
    }
    pit_info_list.append(pit_info_dict)
# Out:
# hs_mm: 975.0, height_bottom_mm: 470.0, depth_top_mm: 505.0
# hs_mm: 800.0, height_bottom_mm: 200.0, depth_top_mm: 600.0
# hs_mm: 1320.0, height_bottom_mm: 620.0, depth_top_mm: 700.0
# hs_mm: 1640.0, height_bottom_mm: 400.0, depth_top_mm: 1240.0
# hs_mm: 710.0, height_bottom_mm: 280.0, depth_top_mm: 430.0
# hs_mm: 1670.0, height_bottom_mm: 680.0, depth_top_mm: 990.0
# hs_mm: 1920.0, height_bottom_mm: 1220.0, depth_top_mm: 700.0
# hs_mm: 1170.0, height_bottom_mm: 540.0, depth_top_mm: 630.0
# hs_mm: 1020.0, height_bottom_mm: 560.0, depth_top_mm: 460.0
# hs_mm: 1450.0, height_bottom_mm: 1010.0, depth_top_mm: 440.0
# hs_mm: 1200.0, height_bottom_mm: 750.0, depth_top_mm: 450.0
# hs_mm: 3670.0, height_bottom_mm: 1280.0, depth_top_mm: 2390.0
# hs_mm: 1400.0, height_bottom_mm: 720.0, depth_top_mm: 680.0
# hs_mm: 1390.0, height_bottom_mm: 970.0, depth_top_mm: 420.0
# hs_mm: 1180.0, height_bottom_mm: 850.0, depth_top_mm: 330.0
# hs_mm: 830.0, height_bottom_mm: 360.0, depth_top_mm: 470.0
# hs_mm: 980.0, height_bottom_mm: 670.0, depth_top_mm: 310.0
# hs_mm: 1280.0, height_bottom_mm: 900.0, depth_top_mm: 380.0
# hs_mm: 2100.0, height_bottom_mm: 320.0, depth_top_mm: 1780.0
# hs_mm: 770.0, height_bottom_mm: 440.0, depth_top_mm: 330.0
# hs_mm: 1170.0, height_bottom_mm: 720.0, depth_top_mm: 450.0
# hs_mm: 2360.0, height_bottom_mm: 430.0, depth_top_mm: 1930.0
# hs_mm: 1830.0, height_bottom_mm: 1210.0, depth_top_mm: 620.0
# hs_mm: 1320.0, height_bottom_mm: 810.0, depth_top_mm: 510.0
# hs_mm: 800.0, height_bottom_mm: 320.0, depth_top_mm: 480.0
# hs_mm: 900.0, height_bottom_mm: 560.0, depth_top_mm: 340.0
# hs_mm: 650.0, height_bottom_mm: 200.0, depth_top_mm: 450.0
# hs_mm: 1600.0, height_bottom_mm: 790.0, depth_top_mm: 810.0
# hs_mm: 660.0, height_bottom_mm: 350.0, depth_top_mm: 310.0
# hs_mm: 1080.0, height_bottom_mm: 650.0, depth_top_mm: 430.0
# hs_mm: 950.0, height_bottom_mm: 640.0, depth_top_mm: 310.0
# hs_mm: 1210.0, height_bottom_mm: 580.0, depth_top_mm: 630.0
# hs_mm: 720.0, height_bottom_mm: 110.0, depth_top_mm: 610.0
# hs_mm: 1220.0, height_bottom_mm: 850.0, depth_top_mm: 370.0
# hs_mm: 1020.0, height_bottom_mm: 400.0, depth_top_mm: 620.0
# hs_mm: 900.0, height_bottom_mm: 730.0, depth_top_mm: 170.0
# hs_mm: 1540.0, height_bottom_mm: 950.0, depth_top_mm: 590.0
# hs_mm: 1550.0, height_bottom_mm: 1300.0, depth_top_mm: 250.0
# hs_mm: 730.0, height_bottom_mm: 0.0, depth_top_mm: 730.0
# hs_mm: 2200.0, height_bottom_mm: 1250.0, depth_top_mm: 950.0
# hs_mm: 450.0, height_bottom_mm: 130.0, depth_top_mm: 320.0
# hs_mm: 920.0, height_bottom_mm: 670.0, depth_top_mm: 250.0
# hs_mm: 800.0, height_bottom_mm: 200.0, depth_top_mm: 600.0
# hs_mm: 1900.0, height_bottom_mm: 1030.0, depth_top_mm: 870.0
# hs_mm: 1170.0, height_bottom_mm: 630.0, depth_top_mm: 540.0
# hs_mm: 1700.0, height_bottom_mm: 1540.0, depth_top_mm: 160.0
# hs_mm: 900.0, height_bottom_mm: 0.0, depth_top_mm: 900.0
# hs_mm: 1000.0, height_bottom_mm: 230.0, depth_top_mm: 770.0
# hs_mm: 1300.0, height_bottom_mm: 940.0, depth_top_mm: 360.0
# hs_mm: 2720.0, height_bottom_mm: 2120.0, depth_top_mm: 600.0
# hs_mm: 2430.0, height_bottom_mm: 2020.0, depth_top_mm: 410.0
# hs_mm: 1870.0, height_bottom_mm: 1600.0, depth_top_mm: 270.0
# hs_mm: 1450.0, height_bottom_mm: 1260.0, depth_top_mm: 190.0
# hs_mm: 1470.0, height_bottom_mm: 1020.0, depth_top_mm: 450.0
# hs_mm: 1130.0, height_bottom_mm: 100.0, depth_top_mm: 1030.0
# hs_mm: 1870.0, height_bottom_mm: 1140.0, depth_top_mm: 730.0
# hs_mm: 940.0, height_bottom_mm: 150.0, depth_top_mm: 790.0
# hs_mm: 1530.0, height_bottom_mm: 940.0, depth_top_mm: 590.0
# hs_mm: 1880.0, height_bottom_mm: 750.0, depth_top_mm: 1130.0
# hs_mm: 1410.0, height_bottom_mm: 1080.0, depth_top_mm: 330.0
# hs_mm: 600.0, height_bottom_mm: 420.0, depth_top_mm: 180.0
# hs_mm: 1860.0, height_bottom_mm: 880.0, depth_top_mm: 980.0
# hs_mm: 1070.0, height_bottom_mm: 590.0, depth_top_mm: 480.0
# hs_mm: 600.0, height_bottom_mm: 90.0, depth_top_mm: 510.0
# hs_mm: 850.0, height_bottom_mm: 470.0, depth_top_mm: 380.0
# hs_mm: 640.0, height_bottom_mm: 450.0, depth_top_mm: 190.0
# hs_mm: 1000.0, height_bottom_mm: 570.0, depth_top_mm: 430.0
# hs_mm: 630.0, height_bottom_mm: 290.0, depth_top_mm: 340.0
# hs_mm: 1080.0, height_bottom_mm: 670.0, depth_top_mm: 410.0
# hs_mm: 1530.0, height_bottom_mm: 940.0, depth_top_mm: 590.0
# hs_mm: 2150.0, height_bottom_mm: 1270.0, depth_top_mm: 880.0
# hs_mm: 1760.0, height_bottom_mm: 260.0, depth_top_mm: 1500.0
# hs_mm: 1300.0, height_bottom_mm: 950.0, depth_top_mm: 350.0
# hs_mm: 1360.0, height_bottom_mm: 740.0, depth_top_mm: 620.0
# hs_mm: 1550.0, height_bottom_mm: 1040.0, depth_top_mm: 510.0
# hs_mm: 1360.0, height_bottom_mm: 700.0, depth_top_mm: 660.0
# hs_mm: 1180.0, height_bottom_mm: 450.0, depth_top_mm: 730.0
# hs_mm: 1030.0, height_bottom_mm: 460.0, depth_top_mm: 570.0
# hs_mm: 1450.0, height_bottom_mm: 1120.0, depth_top_mm: 330.0
# hs_mm: 1120.0, height_bottom_mm: 310.0, depth_top_mm: 810.0
# hs_mm: 842.0, height_bottom_mm: 580.0, depth_top_mm: 262.0
# hs_mm: 1840.0, height_bottom_mm: 780.0, depth_top_mm: 1060.0
# hs_mm: 950.0, height_bottom_mm: 590.0, depth_top_mm: 360.0
# hs_mm: 560.0, height_bottom_mm: 320.0, depth_top_mm: 240.0
# hs_mm: 950.0, height_bottom_mm: 680.0, depth_top_mm: 270.0
# hs_mm: 1450.0, height_bottom_mm: 870.0, depth_top_mm: 580.0
# hs_mm: 1210.0, height_bottom_mm: 510.0, depth_top_mm: 700.0
# hs_mm: 1300.0, height_bottom_mm: 680.0, depth_top_mm: 620.0
# hs_mm: 1350.0, height_bottom_mm: 780.0, depth_top_mm: 570.0
# hs_mm: 950.0, height_bottom_mm: 250.0, depth_top_mm: 700.0
# hs_mm: 1440.0, height_bottom_mm: 580.0, depth_top_mm: 860.0
# hs_mm: 1300.0, height_bottom_mm: 520.0, depth_top_mm: 780.0
# hs_mm: 1550.0, height_bottom_mm: 630.0, depth_top_mm: 920.0
# hs_mm: 900.0, height_bottom_mm: 550.0, depth_top_mm: 350.0
# hs_mm: 730.0, height_bottom_mm: 370.0, depth_top_mm: 360.0
# hs_mm: 900.0, height_bottom_mm: 450.0, depth_top_mm: 450.0
# hs_mm: 870.0, height_bottom_mm: 550.0, depth_top_mm: 320.0
# hs_mm: 1150.0, height_bottom_mm: 680.0, depth_top_mm: 470.0
# hs_mm: 710.0, height_bottom_mm: 230.0, depth_top_mm: 480.0
# hs_mm: 1050.0, height_bottom_mm: 550.0, depth_top_mm: 500.0
# hs_mm: 2170.0, height_bottom_mm: 1810.0, depth_top_mm: 360.0
# hs_mm: 700.0, height_bottom_mm: 470.0, depth_top_mm: 230.0
# hs_mm: 1410.0, height_bottom_mm: 980.0, depth_top_mm: 430.0
# hs_mm: 1550.0, height_bottom_mm: 740.0, depth_top_mm: 810.0
# hs_mm: 810.0, height_bottom_mm: 530.0, depth_top_mm: 280.0
# hs_mm: 2070.0, height_bottom_mm: 1770.0, depth_top_mm: 300.0
# hs_mm: 1700.0, height_bottom_mm: 720.0, depth_top_mm: 980.0
# hs_mm: 1340.0, height_bottom_mm: 1000.0, depth_top_mm: 340.0
# hs_mm: 880.0, height_bottom_mm: 570.0, depth_top_mm: 310.0
# hs_mm: 1470.0, height_bottom_mm: 1180.0, depth_top_mm: 290.0
# hs_mm: 1240.0, height_bottom_mm: 720.0, depth_top_mm: 520.0
# hs_mm: 1700.0, height_bottom_mm: 460.0, depth_top_mm: 1240.0
# hs_mm: 1780.0, height_bottom_mm: 1230.0, depth_top_mm: 550.0
# hs_mm: 1830.0, height_bottom_mm: 1210.0, depth_top_mm: 620.0
# hs_mm: 1220.0, height_bottom_mm: 160.0, depth_top_mm: 1060.0
# hs_mm: 3670.0, height_bottom_mm: 1280.0, depth_top_mm: 2390.0
# hs_mm: 1240.0, height_bottom_mm: 840.0, depth_top_mm: 400.0
# hs_mm: 900.0, height_bottom_mm: 640.0, depth_top_mm: 260.0
# hs_mm: 1350.0, height_bottom_mm: 150.0, depth_top_mm: 1200.0
# hs_mm: 1050.0, height_bottom_mm: 780.0, depth_top_mm: 270.0
# hs_mm: 1520.0, height_bottom_mm: 460.0, depth_top_mm: 1060.0
# hs_mm: 975.0, height_bottom_mm: 470.0, depth_top_mm: 505.0
# hs_mm: 800.0, height_bottom_mm: 150.0, depth_top_mm: 650.0
# hs_mm: 910.0, height_bottom_mm: 600.0, depth_top_mm: 310.0
# hs_mm: 1850.0, height_bottom_mm: 880.0, depth_top_mm: 970.0
# hs_mm: 1000.0, height_bottom_mm: 580.0, depth_top_mm: 420.0
# hs_mm: 1900.0, height_bottom_mm: 1360.0, depth_top_mm: 540.0
# hs_mm: 2170.0, height_bottom_mm: 1600.0, depth_top_mm: 570.0
# hs_mm: 5200.0, height_bottom_mm: 2700.0, depth_top_mm: 2500.0
# hs_mm: 800.0, height_bottom_mm: 480.0, depth_top_mm: 320.0
# hs_mm: 1240.0, height_bottom_mm: 840.0, depth_top_mm: 400.0
# hs_mm: 750.0, height_bottom_mm: 600.0, depth_top_mm: 150.0
# hs_mm: 1500.0, height_bottom_mm: 780.0, depth_top_mm: 720.0
# hs_mm: 740.0, height_bottom_mm: 400.0, depth_top_mm: 340.0
# hs_mm: 1670.0, height_bottom_mm: 660.0, depth_top_mm: 1010.0
# hs_mm: 1450.0, height_bottom_mm: 740.0, depth_top_mm: 710.0
# hs_mm: 830.0, height_bottom_mm: 590.0, depth_top_mm: 240.0
# hs_mm: 780.0, height_bottom_mm: 520.0, depth_top_mm: 260.0
# hs_mm: 1490.0, height_bottom_mm: 1240.0, depth_top_mm: 250.0
# hs_mm: 1250.0, height_bottom_mm: 800.0, depth_top_mm: 450.0
# hs_mm: 2070.0, height_bottom_mm: 910.0, depth_top_mm: 1160.0
# hs_mm: 1700.0, height_bottom_mm: 1110.0, depth_top_mm: 590.0
# hs_mm: 1880.0, height_bottom_mm: 980.0, depth_top_mm: 900.0
# hs_mm: 530.0, height_bottom_mm: 100.0, depth_top_mm: 430.0
# hs_mm: 750.0, height_bottom_mm: 0.0, depth_top_mm: 750.0
# hs_mm: 1200.0, height_bottom_mm: 480.0, depth_top_mm: 720.0
# hs_mm: 1060.0, height_bottom_mm: 970.0, depth_top_mm: 90.0
# hs_mm: 1300.0, height_bottom_mm: 990.0, depth_top_mm: 310.0
# hs_mm: 1920.0, height_bottom_mm: 800.0, depth_top_mm: 1120.0
# hs_mm: 1860.0, height_bottom_mm: 1300.0, depth_top_mm: 560.0
# hs_mm: 1450.0, height_bottom_mm: 980.0, depth_top_mm: 470.0
# hs_mm: 1250.0, height_bottom_mm: 800.0, depth_top_mm: 450.0
# hs_mm: 250.0, height_bottom_mm: 250.0, depth_top_mm: 0.0
# hs_mm: 1160.0, height_bottom_mm: 600.0, depth_top_mm: 560.0
# hs_mm: 1200.0, height_bottom_mm: 260.0, depth_top_mm: 940.0
# hs_mm: 1050.0, height_bottom_mm: 480.0, depth_top_mm: 570.0
# hs_mm: 3670.0, height_bottom_mm: 1280.0, depth_top_mm: 2390.0
# hs_mm: 3000.0, height_bottom_mm: 1470.0, depth_top_mm: 1530.0
# hs_mm: 1080.0, height_bottom_mm: 610.0, depth_top_mm: 470.0
# hs_mm: 1200.0, height_bottom_mm: 450.0, depth_top_mm: 750.0
# hs_mm: 1350.0, height_bottom_mm: 930.0, depth_top_mm: 420.0
# hs_mm: 710.0, height_bottom_mm: 410.0, depth_top_mm: 300.0
# hs_mm: 1690.0, height_bottom_mm: 1120.0, depth_top_mm: 570.0
# hs_mm: 1120.0, height_bottom_mm: 240.0, depth_top_mm: 880.0
# hs_mm: 1350.0, height_bottom_mm: 1050.0, depth_top_mm: 300.0
# hs_mm: 1110.0, height_bottom_mm: 570.0, depth_top_mm: 540.0
# hs_mm: 1400.0, height_bottom_mm: 360.0, depth_top_mm: 1040.0
# hs_mm: 1040.0, height_bottom_mm: 200.0, depth_top_mm: 840.0
# hs_mm: 1500.0, height_bottom_mm: 1040.0, depth_top_mm: 460.0
# hs_mm: 1650.0, height_bottom_mm: 1030.0, depth_top_mm: 620.0
# hs_mm: 650.0, height_bottom_mm: 400.0, depth_top_mm: 250.0
# hs_mm: 2770.0, height_bottom_mm: 1820.0, depth_top_mm: 950.0
# hs_mm: 800.0, height_bottom_mm: 390.0, depth_top_mm: 410.0
# hs_mm: 1700.0, height_bottom_mm: 1020.0, depth_top_mm: 680.0
# hs_mm: 2300.0, height_bottom_mm: 1330.0, depth_top_mm: 970.0
# hs_mm: 1150.0, height_bottom_mm: 410.0, depth_top_mm: 740.0
# hs_mm: 2000.0, height_bottom_mm: 510.0, depth_top_mm: 1490.0
# hs_mm: 1650.0, height_bottom_mm: 990.0, depth_top_mm: 660.0
# hs_mm: 1211.0, height_bottom_mm: 700.0, depth_top_mm: 511.0
# hs_mm: 901.0, height_bottom_mm: 640.0, depth_top_mm: 261.0
# hs_mm: 1340.0, height_bottom_mm: 640.0, depth_top_mm: 700.0
# hs_mm: 2170.0, height_bottom_mm: 1600.0, depth_top_mm: 570.0
# hs_mm: 1050.0, height_bottom_mm: 430.0, depth_top_mm: 620.0
# hs_mm: 1530.0, height_bottom_mm: 950.0, depth_top_mm: 580.0
# hs_mm: 1290.0, height_bottom_mm: 530.0, depth_top_mm: 760.0
# hs_mm: 1560.0, height_bottom_mm: 710.0, depth_top_mm: 850.0
# hs_mm: 890.0, height_bottom_mm: 590.0, depth_top_mm: 300.0
# hs_mm: 830.0, height_bottom_mm: 290.0, depth_top_mm: 540.0
# hs_mm: 1490.0, height_bottom_mm: 920.0, depth_top_mm: 570.0
# hs_mm: 1400.0, height_bottom_mm: 1200.0, depth_top_mm: 200.0
# hs_mm: 1440.0, height_bottom_mm: 940.0, depth_top_mm: 500.0
# hs_mm: 750.0, height_bottom_mm: 200.0, depth_top_mm: 550.0
# hs_mm: 910.0, height_bottom_mm: 600.0, depth_top_mm: 310.0
# hs_mm: 1020.0, height_bottom_mm: 760.0, depth_top_mm: 260.0
# hs_mm: 1850.0, height_bottom_mm: 1000.0, depth_top_mm: 850.0
# hs_mm: 2670.0, height_bottom_mm: 2160.0, depth_top_mm: 510.0
# hs_mm: 1200.0, height_bottom_mm: 780.0, depth_top_mm: 420.0
# hs_mm: 1830.0, height_bottom_mm: 0.0, depth_top_mm: 1830.0
# hs_mm: 1350.0, height_bottom_mm: 780.0, depth_top_mm: 570.0
# hs_mm: 1170.0, height_bottom_mm: 600.0, depth_top_mm: 570.0
# hs_mm: 2000.0, height_bottom_mm: 500.0, depth_top_mm: 1500.0
# hs_mm: 1780.0, height_bottom_mm: 1600.0, depth_top_mm: 180.0
# hs_mm: 870.0, height_bottom_mm: 580.0, depth_top_mm: 290.0
# hs_mm: 1120.0, height_bottom_mm: 590.0, depth_top_mm: 530.0
# hs_mm: 1300.0, height_bottom_mm: 370.0, depth_top_mm: 930.0
# hs_mm: 1230.0, height_bottom_mm: 250.0, depth_top_mm: 980.0
# hs_mm: 800.0, height_bottom_mm: 460.0, depth_top_mm: 340.0
# hs_mm: 1200.0, height_bottom_mm: 400.0, depth_top_mm: 800.0
# hs_mm: 1750.0, height_bottom_mm: 1170.0, depth_top_mm: 580.0
# hs_mm: 1000.0, height_bottom_mm: 500.0, depth_top_mm: 500.0
# hs_mm: 1080.0, height_bottom_mm: 550.0, depth_top_mm: 530.0
# hs_mm: 900.0, height_bottom_mm: 160.0, depth_top_mm: 740.0
# hs_mm: 1000.0, height_bottom_mm: 720.0, depth_top_mm: 280.0
# hs_mm: 2000.0, height_bottom_mm: 1700.0, depth_top_mm: 300.0
# hs_mm: 1530.0, height_bottom_mm: 670.0, depth_top_mm: 860.0
# hs_mm: 1460.0, height_bottom_mm: 680.0, depth_top_mm: 780.0
# hs_mm: 2200.0, height_bottom_mm: 1640.0, depth_top_mm: 560.0
# hs_mm: 1180.0, height_bottom_mm: 450.0, depth_top_mm: 730.0
# hs_mm: 1820.0, height_bottom_mm: 1000.0, depth_top_mm: 820.0
# hs_mm: 1320.0, height_bottom_mm: 640.0, depth_top_mm: 680.0
# hs_mm: 1500.0, height_bottom_mm: 1070.0, depth_top_mm: 430.0
# hs_mm: 1630.0, height_bottom_mm: 800.0, depth_top_mm: 830.0
# hs_mm: 1900.0, height_bottom_mm: 1280.0, depth_top_mm: 620.0
# hs_mm: 2560.0, height_bottom_mm: 540.0, depth_top_mm: 2020.0
# hs_mm: 1880.0, height_bottom_mm: 930.0, depth_top_mm: 950.0
# hs_mm: 610.0, height_bottom_mm: 170.0, depth_top_mm: 440.0
# hs_mm: 1810.0, height_bottom_mm: 600.0, depth_top_mm: 1210.0
# hs_mm: 1250.0, height_bottom_mm: 680.0, depth_top_mm: 570.0
# hs_mm: 1580.0, height_bottom_mm: 740.0, depth_top_mm: 840.0
# hs_mm: 1290.0, height_bottom_mm: 490.0, depth_top_mm: 800.0
# hs_mm: 1220.0, height_bottom_mm: 150.0, depth_top_mm: 1070.0
# hs_mm: 1290.0, height_bottom_mm: 530.0, depth_top_mm: 760.0
# hs_mm: 1150.0, height_bottom_mm: 760.0, depth_top_mm: 390.0
# hs_mm: 1060.0, height_bottom_mm: 650.0, depth_top_mm: 410.0
# hs_mm: 980.0, height_bottom_mm: 200.0, depth_top_mm: 780.0
# hs_mm: 2700.0, height_bottom_mm: 1140.0, depth_top_mm: 1560.0
# hs_mm: 2430.0, height_bottom_mm: 2020.0, depth_top_mm: 410.0
# hs_mm: 1300.0, height_bottom_mm: 600.0, depth_top_mm: 700.0
# hs_mm: 1220.0, height_bottom_mm: 500.0, depth_top_mm: 720.0
# hs_mm: 760.0, height_bottom_mm: 340.0, depth_top_mm: 420.0
# hs_mm: 650.0, height_bottom_mm: 530.0, depth_top_mm: 120.0
# hs_mm: 1300.0, height_bottom_mm: 950.0, depth_top_mm: 350.0
# hs_mm: 300.0, height_bottom_mm: 150.0, depth_top_mm: 150.0
# hs_mm: 420.0, height_bottom_mm: 180.0, depth_top_mm: 240.0
# hs_mm: 480.0, height_bottom_mm: 200.0, depth_top_mm: 280.0
# hs_mm: 1410.0, height_bottom_mm: 760.0, depth_top_mm: 650.0
# hs_mm: 2200.0, height_bottom_mm: 1080.0, depth_top_mm: 1120.0
# hs_mm: 1750.0, height_bottom_mm: 1440.0, depth_top_mm: 310.0
# hs_mm: 900.0, height_bottom_mm: 520.0, depth_top_mm: 380.0
# hs_mm: 6000.0, height_bottom_mm: 5280.0, depth_top_mm: 720.0
# hs_mm: 1620.0, height_bottom_mm: 640.0, depth_top_mm: 980.0
# hs_mm: 1460.0, height_bottom_mm: 1180.0, depth_top_mm: 280.0
# hs_mm: 1150.0, height_bottom_mm: 240.0, depth_top_mm: 910.0
# hs_mm: 1620.0, height_bottom_mm: 1060.0, depth_top_mm: 560.0
# hs_mm: 1530.0, height_bottom_mm: 1120.0, depth_top_mm: 410.0
# hs_mm: 870.0, height_bottom_mm: 510.0, depth_top_mm: 360.0
# hs_mm: 1400.0, height_bottom_mm: 1240.0, depth_top_mm: 160.0
# hs_mm: 610.0, height_bottom_mm: 110.0, depth_top_mm: 500.0
# hs_mm: 1500.0, height_bottom_mm: 1100.0, depth_top_mm: 400.0
# hs_mm: 1880.0, height_bottom_mm: 1100.0, depth_top_mm: 780.0
# hs_mm: 1270.0, height_bottom_mm: 710.0, depth_top_mm: 560.0
# hs_mm: 480.0, height_bottom_mm: 390.0, depth_top_mm: 90.0
# hs_mm: 420.0, height_bottom_mm: 180.0, depth_top_mm: 240.0
# hs_mm: 560.0, height_bottom_mm: 240.0, depth_top_mm: 320.0
# hs_mm: 1410.0, height_bottom_mm: 860.0, depth_top_mm: 550.0
# hs_mm: 700.0, height_bottom_mm: 400.0, depth_top_mm: 300.0
# hs_mm: 580.0, height_bottom_mm: 150.0, depth_top_mm: 430.0
# hs_mm: 580.0, height_bottom_mm: 290.0, depth_top_mm: 290.0
# hs_mm: 1050.0, height_bottom_mm: 760.0, depth_top_mm: 290.0
# hs_mm: 1000.0, height_bottom_mm: 830.0, depth_top_mm: 170.0
# hs_mm: 1690.0, height_bottom_mm: 800.0, depth_top_mm: 890.0
# hs_mm: 870.0, height_bottom_mm: 340.0, depth_top_mm: 530.0
# hs_mm: 2700.0, height_bottom_mm: 2000.0, depth_top_mm: 700.0
# hs_mm: 900.0, height_bottom_mm: 200.0, depth_top_mm: 700.0
# hs_mm: 750.0, height_bottom_mm: 510.0, depth_top_mm: 240.0
# hs_mm: 1800.0, height_bottom_mm: 960.0, depth_top_mm: 840.0
# hs_mm: 1220.0, height_bottom_mm: 480.0, depth_top_mm: 740.0
# hs_mm: 1080.0, height_bottom_mm: 680.0, depth_top_mm: 400.0
# hs_mm: 1100.0, height_bottom_mm: 500.0, depth_top_mm: 600.0
# hs_mm: 1150.0, height_bottom_mm: 330.0, depth_top_mm: 820.0
# hs_mm: 930.0, height_bottom_mm: 390.0, depth_top_mm: 540.0
# hs_mm: 1700.0, height_bottom_mm: 850.0, depth_top_mm: 850.0
# hs_mm: 1490.0, height_bottom_mm: 860.0, depth_top_mm: 630.0
# hs_mm: 1440.0, height_bottom_mm: 1150.0, depth_top_mm: 290.0
# hs_mm: 1600.0, height_bottom_mm: 630.0, depth_top_mm: 970.0
# hs_mm: 750.0, height_bottom_mm: 560.0, depth_top_mm: 190.0
# hs_mm: 1180.0, height_bottom_mm: 530.0, depth_top_mm: 650.0
# hs_mm: 1400.0, height_bottom_mm: 400.0, depth_top_mm: 1000.0
# hs_mm: 2250.0, height_bottom_mm: 1650.0, depth_top_mm: 600.0
# hs_mm: 2800.0, height_bottom_mm: 2270.0, depth_top_mm: 530.0
# hs_mm: 1780.0, height_bottom_mm: 1600.0, depth_top_mm: 180.0
# hs_mm: 1810.0, height_bottom_mm: 1420.0, depth_top_mm: 390.0

# %%
if run_weac:
    data_rows = []
    error_pits = []
    for (fp, pit), pit_info_dict in tqdm(
        zip(avalanche_pits_with_layer_of_concern, pit_info_list),
        total=len(avalanche_pits_with_layer_of_concern),
        desc="Processing avalanche pits",
    ):
        scenario_config = ScenarioConfig(
            phi=pit_info_dict["Slope Angle"],
            system_type="skier",
        )
        try:
            pit_info_dict, layers, weaklayer = eval_avalanche_pit(
                pit, 
                pit_info_dict, 
                scenario_config, 
                segments, 
                weak_layer,
                criteria_evaluator)
            data_rows.append(pit_info_dict)
        except Exception as e:
            error_pits.append(pit)
            print(f"Error processing pit {pit.snowpit.core_info.pit_id}: {e}")
            continue

    print(f"Number of pits with errors: {len(error_pits)}")
    print(f"Number of pits processed: {len(data_rows)}")
    print(f"Number of pits total: {len(avalanche_pits_with_layer_of_concern)}")

    df = pd.DataFrame(data_rows)
    print(df.head())
    df.to_csv(csv_file, index=False)
else:
    df = pd.read_csv(csv_file)
# Out:
# Processing avalanche pits:   0%|          | 0/292 [00:00<?, ?it/s]
# Error Raised during WEAC Analysis
# Error processing pit 2c59aaf0-d59e-4749-91ab-4e7b9af16777: 1 validation error for ModelInput
#   Value error, At least one layer is required [type=value_error, input_value={'weak_layer': WeakLayer(...  [0.],
#        [0.]]))]}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.12/v/value_error
# Number of pits with errors: 1
# Number of pits processed: 291
# Number of pits total: 292
#   Slope Angle      HS  Profile Depth  WL_Depth  max_stress  impact_criterion  \
# 0          37   975.0          975.0     505.0    0.019212         70.993092
# 1          40   800.0          800.0     600.0    0.014949         48.273103
# 2          38  1320.0         1320.0     700.0    0.024441         67.810873
# 3          38  1640.0         1640.0    1240.0    0.087140        109.875507
# 4          30   710.0          710.0     430.0    0.013905         69.809697
#
#    coupled_criterion  sserr_result  touchdown_distance  ss_max_Sxx_norm  \
# 0         184.723349      2.848244         1296.382704         1.843323
# 1         134.283460      2.489557         1019.143313         2.819140
# 2         180.684046      3.157320         1203.742271         1.904126
# 3         259.030083      5.843737         1634.043595         1.357448
# 4         177.260520      2.438798         1292.760103         1.576260
#
#    slab_tensile_criterion
# 0                0.251953
# 1                0.155629
# 2                0.234043
# 3                0.155949
# 4                0.348624

# %%
sserr_median = df["sserr_result"].median()
sserr_mean = df["sserr_result"].mean()
sserr_std = df["sserr_result"].std()

print(f"SSERR Median: {sserr_median}")
print(f"SSERR Mean: {sserr_mean}")
print(f"SSERR Std: {sserr_std}")

cc_median = df["coupled_criterion"].median()
cc_mean = df["coupled_criterion"].mean()
cc_std = df["coupled_criterion"].std()

print(f"CC Median: {cc_median}")
print(f"CC Mean: {cc_mean}")
print(f"CC Std: {cc_std}")

max_stress_median = df["max_stress"].median()
max_stress_mean = df["max_stress"].mean()
max_stress_std = df["max_stress"].std()

print(f"MAX STRESS Median: {max_stress_median}")
print(f"MAX STRESS Mean: {max_stress_mean}")
print(f"MAX STRESS Std: {max_stress_std}")

ss_max_Sxx_norm_median = df["ss_max_Sxx_norm"].median()
ss_max_Sxx_norm_mean = df["ss_max_Sxx_norm"].mean()
ss_max_Sxx_norm_std = df["ss_max_Sxx_norm"].std()

print(f"SS MAX SXX NORM Median: {ss_max_Sxx_norm_median}")
print(f"SS MAX SXX NORM Mean: {ss_max_Sxx_norm_mean}")
print(f"SS MAX SXX NORM Std: {ss_max_Sxx_norm_std}")

slab_tensile_criterion_median = df["slab_tensile_criterion"].median()
slab_tensile_criterion_mean = df["slab_tensile_criterion"].mean()
slab_tensile_criterion_std = df["slab_tensile_criterion"].std()

print(f"SLAB TENSILE CRITERION Median: {slab_tensile_criterion_median}")
print(f"SLAB TENSILE CRITERION Mean: {slab_tensile_criterion_mean}")
print(f"SLAB TENSILE CRITERION Std: {slab_tensile_criterion_std}")
# Out:
# SSERR Median: 3.157319792631495
# SSERR Mean: 3.939008414049664
# SSERR Std: 3.082231266019077
# CC Median: 225.04120839130087
# CC Mean: 250.22636415933198
# CC Std: 137.87596820917858
# MAX STRESS Median: 0.024548825416716148
# MAX STRESS Mean: 0.06163399452824263
# MAX STRESS Std: 0.12541547155497765
# SS MAX SXX NORM Median: 1.7589890521364187
# SS MAX SXX NORM Mean: 1.848936811046489
# SS MAX SXX NORM Std: 0.4931281582243675
# SLAB TENSILE CRITERION Median: 0.21543408360128619
# SLAB TENSILE CRITERION Mean: 0.21413302637269957
# SLAB TENSILE CRITERION Std: 0.09431761305683263

# %%
import plotly.graph_objects as go

fig = go.Figure()
fig.add_trace(go.Scatter(x=df["WL_Depth"], y=df["impact_criterion"], mode="markers", name="Impact Criterion", marker=dict(color="red")))
fig.update_layout(xaxis_title="WL Depth (mm)", yaxis_title="Impact Criterion")
fig.show()

fig = go.Figure()
fig.add_trace(go.Scatter(x=df["WL_Depth"], y=df["coupled_criterion"], mode="markers", name="Coupled Criterion", marker=dict(color="blue")))
fig.update_layout(xaxis_title="WL Depth (mm)", yaxis_title="Coupled Criterion")
fig.show()

fig = go.Figure()
fig.add_trace(go.Scatter(x=df["WL_Depth"], y=df["sserr_result"], mode="markers", name="SSERR", marker=dict(color="green")))
fig.update_layout(xaxis_title="WL Depth (mm)", yaxis_title="SSERR")
fig.show()

fig = go.Figure()
fig.add_trace(go.Scatter(x=df["WL_Depth"], y=df["touchdown_distance"], mode="markers", name="Touchdown Distance", marker=dict(color="yellow")))
fig.update_layout(xaxis_title="WL Depth (mm)", yaxis_title="Touchdown Distance")
fig.show()

fig = go.Figure()
fig.add_trace(go.Scatter(x=df["WL_Depth"], y=df["max_stress"], mode="markers", name="Max Stress", marker=dict(color="red")))
fig.update_layout(xaxis_title="WL Depth (mm)", yaxis_title="Max Stress")
fig.show()

fig = go.Figure()
fig.add_trace(go.Scatter(x=df["WL_Depth"], y=df["ss_max_Sxx_norm"], mode="markers", name="SS MAX SXX NORM", marker=dict(color="blue")))
fig.update_layout(xaxis_title="WL Depth (mm)", yaxis_title="SS MAX SXX NORM")
fig.show()

fig = go.Figure()
fig.add_trace(go.Scatter(x=df["WL_Depth"], y=df["slab_tensile_criterion"], mode="markers", name="SLAB TENSILE CRITERION", marker=dict(color="green")))
fig.update_layout(xaxis_title="WL Depth (mm)", yaxis_title="SLAB TENSILE CRITERION")
fig.show()

# %%
import matplotlib.pyplot as plt

# Bin wl depths according to 10 mm intervals
wl_depths = df["WL_Depth"]
max_wl_depth = max(wl_depths)
min_wl_depth = min(wl_depths)

# Create bins
bin_width = 50
bins = np.arange(min_wl_depth, max_wl_depth + bin_width, bin_width)

# Use matplotlib's histogram which handles this automatically
plt.hist(wl_depths, bins=bins, edgecolor='black', alpha=0.7)
plt.xlabel("WL Depth (mm)")
plt.ylabel("Number of Pits")
plt.title("Number of Pits in Each WL Depth Bin")
plt.show()

# %%
import plotly.graph_objects as go
import pandas as pd
import numpy as np

wl_depths = df["WL_Depth"]
df = df[df["WL_Depth"] > discard_pits_with_wl_above]

# %% [markdown]
# ### Coupled Criterion

# %%
# Plot cumulative distribution of coupled criterion
cc = df["coupled_criterion"][~np.isnan(df["coupled_criterion"])]
sorted_cc = np.sort(cc)
cdf = np.arange(1, len(sorted_cc) + 1) / len(sorted_cc)

fig = go.Figure()
fig.add_trace(go.Scatter(x=sorted_cc, y=cdf, mode="markers", name="Coupled Criterion", marker=dict(color="red")))
fig.update_layout(xaxis_title="Weight (kg)", yaxis_title="Cumulative Distribution")
fig.show()

# %%
from scipy import stats

# Fit a normal distribution to the data
params_norm = stats.norm.fit(cc)
cdf_values_norm = stats.norm.cdf(sorted_cc, *params_norm)

# Fit a log-normal distribution to the data
params_lognorm = stats.lognorm.fit(cc)
cdf_values_lognorm = stats.lognorm.cdf(sorted_cc, *params_lognorm)

# # Fit an exponential distribution to the data
# params_expon = stats.expon.fit(cc)
# cdf_values_expon = stats.expon.cdf(sorted_cc, *params_expon)

# Fit an Exponential Normal distribution to the data
params_exponnorm = stats.exponnorm.fit(cc)
cdf_values_exponnorm = stats.exponnorm.cdf(sorted_cc, *params_exponnorm)
print(params_exponnorm)


fig = go.Figure()
fig.add_trace(go.Scatter(x=sorted_cc, y=cdf_values_norm, mode="lines", name="Normal"))
fig.add_trace(go.Scatter(x=sorted_cc, y=cdf_values_lognorm, mode="lines", name="Lognormal"))
# fig.add_trace(go.Scatter(x=sorted_cc, y=cdf_values_expon, mode="lines", name="Exponential"))
fig.add_trace(go.Scatter(x=sorted_cc, y=cdf_values_exponnorm, mode="lines", name="Exponential Normal"))
fig.add_trace(go.Scatter(x=sorted_cc, y=cdf, mode="markers", name="Data"))
fig.show()
# Out:
# (np.float64(2.1821100126666053), np.float64(117.72698049430437), np.float64(60.72077615464323))

# %% [markdown]
# ## Steady State Energy Release Rate

# %%
import plotly.graph_objects as go
import pandas as pd
import numpy as np

# Plot cumulative distribution of coupled criterion
sserr = df["sserr_result"][~np.isnan(df["sserr_result"])]
sorted_sserr = np.sort(sserr)
cdf = np.arange(1, len(sorted_sserr) + 1) / len(sorted_sserr)

fig = go.Figure()
fig.add_trace(go.Scatter(x=sorted_sserr, y=cdf, mode="markers", name="SSERR", marker=dict(color="red")))
fig.update_layout(xaxis_title="SSERR", yaxis_title="Cumulative Distribution")
fig.show()

# %%
from scipy import stats

# # Fit a normal distribution to the data
# params_norm = stats.norm.fit(sserr)
# cdf_values_norm = stats.norm.cdf(sorted_sserr, *params_norm)

# Fit a log-normal distribution to the data
params_lognorm = stats.lognorm.fit(sserr)
cdf_values_lognorm = stats.lognorm.cdf(sorted_sserr, *params_lognorm)
print(params_lognorm)

# # Fit an exponential distribution to the data
# params_expon = stats.expon.fit(sserr)
# cdf_values_expon = stats.expon.cdf(sorted_sserr, *params_expon)

# Fit an Exponential Normal distribution to the data
params_exponnorm = stats.exponnorm.fit(sserr)
cdf_values_exponnorm = stats.exponnorm.cdf(sorted_sserr, *params_exponnorm)


fig = go.Figure()
# fig.add_trace(go.Scatter(x=sorted_sserr, y=cdf_values_norm, mode="lines", name="Normal"))
fig.add_trace(go.Scatter(x=sorted_sserr, y=cdf_values_lognorm, mode="lines", name="Lognormal"))
# fig.add_trace(go.Scatter(x=sorted_sserr, y=cdf_values_expon, mode="lines", name="Exponential"))
fig.add_trace(go.Scatter(x=sorted_sserr, y=cdf_values_exponnorm, mode="lines", name="Exponential Normal"))
fig.add_trace(go.Scatter(x=sorted_sserr, y=cdf, mode="markers", name="Data"))
fig.show()
# Out:
# (np.float64(0.6657784272076132), -0.09376769618612446, np.float64(3.2223214289568745))

# %% [markdown]
# ## Max Stress

# %%
import plotly.graph_objects as go
import pandas as pd
import numpy as np

# Plot cumulative distribution of coupled criterion
max_stress = df["max_stress"][~np.isnan(df["max_stress"])]
sorted_max_stress = np.sort(max_stress)
cdf = np.arange(1, len(sorted_max_stress) + 1) / len(sorted_max_stress)

fig = go.Figure()
fig.add_trace(go.Scatter(x=sorted_max_stress, y=cdf, mode="markers", name="max_stress", marker=dict(color="red")))
fig.update_layout(xaxis_title="max_stress", yaxis_title="Cumulative Distribution")
fig.show()

# %%
from scipy import stats

# # Fit a normal distribution to the data
params_norm = stats.norm.fit(max_stress)
cdf_values_norm = stats.norm.cdf(sorted_max_stress, *params_norm)

# Fit a log-normal distribution to the data
params_lognorm = stats.lognorm.fit(max_stress)
cdf_values_lognorm = stats.lognorm.cdf(sorted_max_stress, *params_lognorm)
print(params_lognorm)

# # Fit an exponential distribution to the data
params_expon = stats.expon.fit(max_stress)
cdf_values_expon = stats.expon.cdf(sorted_max_stress, *params_expon)

# Fit an Exponential Normal distribution to the data
params_exponnorm = stats.exponnorm.fit(max_stress)
cdf_values_exponnorm = stats.exponnorm.cdf(sorted_max_stress, *params_exponnorm)


fig = go.Figure()
fig.add_trace(go.Scatter(x=sorted_max_stress, y=cdf_values_norm, mode="lines", name="Normal"))
fig.add_trace(go.Scatter(x=sorted_max_stress, y=cdf_values_lognorm, mode="lines", name="Lognormal"))
fig.add_trace(go.Scatter(x=sorted_max_stress, y=cdf_values_expon, mode="lines", name="Exponential"))
fig.add_trace(go.Scatter(x=sorted_max_stress, y=cdf_values_exponnorm, mode="lines", name="Exponential Normal"))
fig.add_trace(go.Scatter(x=sorted_max_stress, y=cdf, mode="markers", name="Data"))
fig.show()
# Out:
# (np.float64(1.3975321083373058), -0.00016871790563175137, np.float64(0.023345346860194006))

# %% [markdown]
# ## Steady State S_xx (normalized)

# %%
import plotly.graph_objects as go
import pandas as pd
import numpy as np

# Plot cumulative distribution of coupled criterion
weight = np.arange(0, 600, 10)
ss_max_Sxx_norm = df["ss_max_Sxx_norm"][~np.isnan(df["ss_max_Sxx_norm"])]
sorted_ss_max_Sxx_norm = np.sort(ss_max_Sxx_norm)
cdf = np.arange(1, len(sorted_ss_max_Sxx_norm) + 1) / len(sorted_ss_max_Sxx_norm)

fig = go.Figure()
fig.add_trace(go.Scatter(x=sorted_ss_max_Sxx_norm, y=cdf, mode="markers", name="SS MAX SXX NORM", marker=dict(color="red")))
fig.update_layout(xaxis_title="SS MAX SXX NORM", yaxis_title="Cumulative Distribution")
fig.show()

# %%
from scipy import stats

# # Fit a normal distribution to the data
params_norm = stats.norm.fit(ss_max_Sxx_norm)
cdf_values_norm = stats.norm.cdf(sorted_ss_max_Sxx_norm, *params_norm)

# Fit a log-normal distribution to the data
params_lognorm = stats.lognorm.fit(ss_max_Sxx_norm)
cdf_values_lognorm = stats.lognorm.cdf(sorted_ss_max_Sxx_norm, *params_lognorm)

# # Fit an exponential distribution to the data
params_expon = stats.expon.fit(ss_max_Sxx_norm)
cdf_values_expon = stats.expon.cdf(sorted_ss_max_Sxx_norm, *params_expon)

# Fit an Exponential Normal distribution to the data
params_exponnorm = stats.exponnorm.fit(ss_max_Sxx_norm)
cdf_values_exponnorm = stats.exponnorm.cdf(sorted_ss_max_Sxx_norm, *params_exponnorm)
print(params_exponnorm)


fig = go.Figure()
fig.add_trace(go.Scatter(x=sorted_ss_max_Sxx_norm, y=cdf_values_norm, mode="lines", name="Normal"))
fig.add_trace(go.Scatter(x=sorted_ss_max_Sxx_norm, y=cdf_values_lognorm, mode="lines", name="Lognormal"))
fig.add_trace(go.Scatter(x=sorted_ss_max_Sxx_norm, y=cdf_values_expon, mode="lines", name="Exponential"))
fig.add_trace(go.Scatter(x=sorted_ss_max_Sxx_norm, y=cdf_values_exponnorm, mode="lines", name="Exponential Normal"))
fig.add_trace(go.Scatter(x=sorted_ss_max_Sxx_norm, y=cdf, mode="markers", name="Data"))
fig.show()
# Out:
# (np.float64(1.7956623148370587), np.float64(1.4523608465771498), np.float64(0.22084848666266566))

# %% [markdown]
# ## Slab Tensile Criterion

# %%
import plotly.graph_objects as go
import pandas as pd
import numpy as np

# Plot cumulative distribution of coupled criterion
weight = np.arange(0, 600, 10)
slab_tensile_criterion = df["slab_tensile_criterion"][~np.isnan(df["slab_tensile_criterion"])]
sorted_slab_tensile_criterion = np.sort(slab_tensile_criterion)
cdf = np.arange(1, len(sorted_slab_tensile_criterion) + 1) / len(sorted_slab_tensile_criterion)

fig = go.Figure()
fig.add_trace(go.Scatter(x=sorted_slab_tensile_criterion, y=cdf, mode="markers", name="SLAB TENSILE CRITERION", marker=dict(color="red")))
fig.update_layout(xaxis_title="SLAB TENSILE CRITERION", yaxis_title="Cumulative Distribution")
fig.show()

# %%
from scipy import stats

# # Fit a normal distribution to the data
params_norm = stats.norm.fit(slab_tensile_criterion)
cdf_values_norm = stats.norm.cdf(sorted_slab_tensile_criterion, *params_norm)

# Fit a log-normal distribution to the data
params_lognorm = stats.lognorm.fit(slab_tensile_criterion)
cdf_values_lognorm = stats.lognorm.cdf(sorted_slab_tensile_criterion, *params_lognorm)
print(params_lognorm)

# # Fit an exponential distribution to the data
params_expon = stats.expon.fit(slab_tensile_criterion)
cdf_values_expon = stats.expon.cdf(sorted_slab_tensile_criterion, *params_expon)

# Fit an Exponential Normal distribution to the data
params_exponnorm = stats.exponnorm.fit(slab_tensile_criterion)
cdf_values_exponnorm = stats.exponnorm.cdf(sorted_slab_tensile_criterion, *params_exponnorm)


fig = go.Figure()
fig.add_trace(go.Scatter(x=sorted_slab_tensile_criterion, y=cdf_values_norm, mode="lines", name="Normal"))
fig.add_trace(go.Scatter(x=sorted_slab_tensile_criterion, y=cdf_values_lognorm, mode="lines", name="Lognormal"))
fig.add_trace(go.Scatter(x=sorted_slab_tensile_criterion, y=cdf_values_expon, mode="lines", name="Exponential"))
fig.add_trace(go.Scatter(x=sorted_slab_tensile_criterion, y=cdf_values_exponnorm, mode="lines", name="Exponential Normal"))
fig.add_trace(go.Scatter(x=sorted_slab_tensile_criterion, y=cdf, mode="markers", name="Data"))
fig.show()
# Out:
# (np.float64(2.9331117259122433e-05), -3209.874412916295, np.float64(3210.0885445618237))
# /home/pillowbeast/Documents/layerwise/.venv/lib/python3.13/site-packages/scipy/stats/_continuous_distns.py:6930: RuntimeWarning:
#
# overflow encountered in divide
